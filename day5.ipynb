# %% [markdown]
# <a href="https://colab.research.google.com/github/aranjaka/dw_matrix_road_sign/blob/master/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
import pandas as pd
import numpy as np
import os
import datetime

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# %load_ext tensorboard

import matplotlib.pyplot as plt
from skimage import color, exposure

from sklearn.metrics import accuracy_score

from hyperopt import hp, STATUS_OK, tpe, Trials, fmin
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
cd '/content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix/matrix_three/dw_matrix_road_sign

# %%
train = pd.read_pickle('data/train.p')
test = pd.read_pickle('data/test.p')

X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# %%
if y_train.ndim == 1: y_train = to_categorical(y_train)
if y_test.ndim == 1: y_test = to_categorical(y_test)

# %%
input_shape = X_train.shape[1:]
num_classes = y_train.shape[1]

# %%
def train_model(model, X_train, y_train, params_fit={}):
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
  
  model.fit(
    X_train, 
    y_train,
    batch_size=params_fit.get('batch_size', 128),
    epochs=params_fit.get('epochs', 5),
    verbose=params_fit.get('verbose', 1),
    validation_data=params_fit.get('validation_data', (X_train, y_train)),
    callbacks= [tensorboard_callback]
 )

  return model

# %%
def predict(model_trained, X_test, y_test, scoring=accuracy_score):

  y_test_norm = np.argmax(y_test, axis=1)

  y_pred_prob = model_trained.predict(X_test)
  y_pred = np.argmax(y_pred_prob, axis=1)

  return scoring(y_test_norm, y_pred)

# %%
def get_cnn_v5(input_shape, num_classes):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),          
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),          
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),          
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),          
    MaxPool2D(),
    Dropout(0.3),

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),          
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),          
    MaxPool2D(),
    Dropout(0.3),

    Flatten(),

    Dense(1024, activation='relu'),
    Dropout(0.3),
    
    Dense(1024, activation='relu'),
    Dropout(0.3),

    Dense(num_classes, activation='softmax'),
  ])

# %%
model = get_cnn_v5(input_shape, num_classes)
model_trained = train_model(model, X_train, y_train, params_fit={})
predict(model_trained, X_test, y_test)
# Out:
# Epoch 1/5
# 272/272 [==============================] - 5s 19ms/step - loss: 2.8235 - accuracy: 0.2326 - val_loss: 1.4236 - val_accuracy: 0.5353
# Epoch 2/5
# 272/272 [==============================] - 5s 17ms/step - loss: 1.0492 - accuracy: 0.6594 - val_loss: 0.2743 - val_accuracy: 0.9233
# Epoch 3/5
# 272/272 [==============================] - 5s 17ms/step - loss: 0.4329 - accuracy: 0.8620 - val_loss: 0.1454 - val_accuracy: 0.9622
# Epoch 4/5
# 272/272 [==============================] - 5s 17ms/step - loss: 0.2735 - accuracy: 0.9162 - val_loss: 0.0587 - val_accuracy: 0.9818
# Epoch 5/5
# 272/272 [==============================] - 5s 17ms/step - loss: 0.1986 - accuracy: 0.9403 - val_loss: 0.0333 - val_accuracy: 0.9910
# 0.9693877551020408

# %%
def get_model(params):
  return Sequential([
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),          
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),          
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_one']),

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),          
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),          
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_two']),

    Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),          
    Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),          
    MaxPool2D(),
    Dropout(params['dropout_cnn_block_three']),

    Flatten(),

    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_one']),
    
    Dense(1024, activation='relu'),
    Dropout(params['dropout_dense_block_two']),

    Dense(num_classes, activation='softmax'),
  ])

# %%
def func_obj(params):
  model = get_model(params)
  model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
  
  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
  
  model.fit(
    X_train, 
    y_train,
    batch_size=128,#int(params.get('batch_size', 128)),
    epochs=5,
    verbose=0,
    
 )

  accuracy = model.evaluate(X_test, y_test)[0]
  print(params, 'accuracy={}'.format(accuracy))

  return {'loss': -accuracy, 'status': STATUS_OK, 'model': model}
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 65

# %%
space = {
    'batch_size': hp.quniform('batch_size', 100, 200, 10),
    'dropout_cnn_block_one': hp.uniform('dropout_cnn_block_one', 0.3, 0.5),
    'dropout_cnn_block_two': hp.uniform('dropout_cnn_block_two', 0.3, 0.5),
    'dropout_cnn_block_three': hp.uniform('dropout_cnn_block_three', 0.3, 0.5),

    'dropout_dense_block_one': hp.uniform('dropout_dense_block_one', 0.3, 0.7),
    'dropout_dense_block_two': hp.uniform('dropout_dense_block_two', 0.3, 0.7),

}

best = fmin(
    func_obj,
    space,
    tpe.suggest,
    30,
    Trials()
)
# Out:
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.9460 - accuracy: 0.8750
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.5019 - accuracy: 0.8293
#
#  25/138 [====>.........................]
#  - ETA: 0s - loss: 0.6756 - accuracy: 0.8263
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.4753 - accuracy: 0.8809
#
#  46/138 [=========>....................]
#  - ETA: 0s - loss: 0.5748 - accuracy: 0.8084
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.5414 - accuracy: 0.8217
#
#  66/138 [=============>................]
#  - ETA: 0s - loss: 0.5248 - accuracy: 0.8163
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.4848 - accuracy: 0.8218
#
#  86/138 [=================>............]
#  - ETA: 0s - loss: 0.4526 - accuracy: 0.8387
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.4210 - accuracy: 0.8516
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.4812 - accuracy: 0.8308
#
# 116/138 [========================>.....]
#  - ETA: 0s - loss: 0.4614 - accuracy: 0.8400
#
# 125/138 [==========================>...]
#  - ETA: 0s - loss: 0.4311 - accuracy: 0.8508
#
# 135/138 [============================>.]
#  - ETA: 0s - loss: 0.4082 - accuracy: 0.8595
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.4039 - accuracy: 0.8615
#
# {'batch_size': 170.0, 'dropout_cnn_block_one': 0.3172981891586632, 'dropout_cnn_block_three': 0.43990605095325164, 'dropout_cnn_block_two': 0.48027093302006185, 'dropout_dense_block_one': 0.6754505110789875, 'dropout_dense_block_two': 0.6410203930956816}
# accuracy=0.4039386808872223
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.0293 - accuracy: 0.6562
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.1550 - accuracy: 0.9591
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.4344 - accuracy: 0.9128
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 0.3022 - accuracy: 0.9402
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.3046 - accuracy: 0.9215
#
#  57/138 [===========>..................]
#  - ETA: 0s - loss: 0.3008 - accuracy: 0.9200
#
#  67/138 [=============>................]
#  - ETA: 0s - loss: 0.2746 - accuracy: 0.9249
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.2429 - accuracy: 0.9338
#
#  88/138 [==================>...........]
#  - ETA: 0s - loss: 0.2175 - accuracy: 0.9400
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.1980 - accuracy: 0.9458
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.2341 - accuracy: 0.9289
#
# 120/138 [=========================>....]
#  - ETA: 0s - loss: 0.2150 - accuracy: 0.9349
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.2039 - accuracy: 0.9385
#
# 138/138 [==============================]
#  - ETA: 0s - loss: 0.1959 - accuracy: 0.9415
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1959 - accuracy: 0.9415
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.38702523350118206, 'dropout_cnn_block_three': 0.3746702709540006, 'dropout_cnn_block_two': 0.46626504755942255, 'dropout_dense_block_one': 0.5434688045403216, 'dropout_dense_block_two': 0.5977843022084701}
# accuracy=0.19587454199790955
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.5545 - accuracy: 0.8125
#
#  12/138 [=>............................]
#  - ETA: 0s - loss: 0.1592 - accuracy: 0.9531
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 0.3008 - accuracy: 0.9247
#
#  31/138 [=====>........................]
#  - ETA: 0s - loss: 0.2554 - accuracy: 0.9325
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.2199 - accuracy: 0.9426
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.2089 - accuracy: 0.9460
#
#  53/138 [==========>...................]
#  - ETA: 0s - loss: 0.2462 - accuracy: 0.9334
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.2274 - accuracy: 0.9370
#
#  73/138 [==============>...............]
#  - ETA: 0s - loss: 0.2217 - accuracy: 0.9375
#
#  84/138 [=================>............]
#  - ETA: 0s - loss: 0.1959 - accuracy: 0.9453
#
#  94/138 [===================>..........]
#  - ETA: 0s - loss: 0.1765 - accuracy: 0.9508
#
# 103/138 [=====================>........]
#  - ETA: 0s - loss: 0.1818 - accuracy: 0.9502
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.1837 - accuracy: 0.9505
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 0.1665 - accuracy: 0.9550
#
# 132/138 [===========================>..]
#  - ETA: 0s - loss: 0.1597 - accuracy: 0.9571
#
# 138/138 [==============================]
#  - 1s 6ms/step - loss: 0.1573 - accuracy: 0.9574
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.35923236860742774, 'dropout_cnn_block_three': 0.4760422514354007, 'dropout_cnn_block_two': 0.42632607582020277, 'dropout_dense_block_one': 0.3713039624552641, 'dropout_dense_block_two': 0.5503184454560605}
# accuracy=0.1573256254196167
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.
#
# {'batch_size': 150.0, 'dropout_cnn_block_one': 0.35734021525109955, 'dropout_cnn_block_three': 0.38661965549366756, 'dropout_cnn_block_two': 0.32214837177828, 'dropout_dense_block_one': 0.3027499965249032, 'dropout_dense_block_two': 0.5475966257800853}
# accuracy=0.16311460733413696
#   1/138 [..............................]
#  - ETA: 0s - loss: 0.5991 - accuracy: 0.7500
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.1772 - accuracy: 0.9471
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.3749 - accuracy: 0.9193
#
#  38/138 [=======>......................]
#  - ETA: 0s - loss: 0.2524 - accuracy: 0.9449
#
#  51/138 [==========>...................]
#  - ETA: 0s - loss: 0.2982 - accuracy: 0.9130
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.3123 - accuracy: 0.9052
#
#  72/138 [==============>...............]
#  - ETA: 0s - loss: 0.2880 - accuracy: 0.9136
#
#  83/138 [=================>............]
#  - ETA: 0s - loss: 0.2540 - accuracy: 0.9236
#
#  95/138 [===================>..........]
#  - ETA: 0s - loss: 0.2281 - accuracy: 0.9322
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.2601 - accuracy: 0.9233
#
# 118/138 [========================>.....]
#  - ETA: 0s - loss: 0.2350 - accuracy: 0.9306
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.2237 - accuracy: 0.9340
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.2193 - accuracy: 0.9325
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2227 - accuracy: 0.9320
#
# {'batch_size': 180.0, 'dropout_cnn_block_one': 0.4742738350161706, 'dropout_cnn_block_three': 0.32983736444055417, 'dropout_cnn_block_two': 0.39173883417330635, 'dropout_dense_block_one': 0.5206119774773219, 'dropout_dense_block_two': 0.44883265545959156}
# accuracy=0.2227100133895874
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.3733 - accuracy: 0.3750
#
#  10/138 [=>............................]
#  - ETA: 0s - loss: 0.9020 - accuracy: 0.6156
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 0.8514 - accuracy: 0.7614
#
#  34/138 [======>.......................]
#  - ETA: 0s - loss: 0.6909 - accuracy: 0.8290
#
#  45/138 [========>.....................]
#  - ETA: 0s - loss: 0.7368 - accuracy: 0.7986
#
#  56/138 [===========>..................]
#  - ETA: 0s - loss: 0.6873 - accuracy: 0.8097
#
#  65/138 [=============>................]
#  - ETA: 0s - loss: 0.6379 - accuracy: 0.8188
#
#  76/138 [===============>..............]
#  - ETA: 0s - loss: 0.5674 - accuracy: 0.8372
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.5051 - accuracy: 0.8563
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.4574 - accuracy: 0.8712
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 0.5206 - accuracy: 0.8469
#
# 119/138 [========================>.....]
#  - ETA: 0s - loss: 0.4847 - accuracy: 0.8571
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0.4524 - accuracy: 0.8675
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.4312 - accuracy: 0.8741
#
# {'batch_size': 130.0, 'dropout_cnn_block_one': 0.3005707204092811, 'dropout_cnn_block_three': 0.42758876051429057, 'dropout_cnn_block_two': 0.4761255576169147, 'dropout_dense_block_one': 0.6855593000155158, 'dropout_dense_block_two': 0.6964139538980528}
# accuracy=0.4311501681804657
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.8830 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.8960 - accuracy: 0.6674
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 1.2677 - accuracy: 0.6198
#
#  36/138 [======>.......................]
#  - ETA: 0s - loss: 1.0366 - accuracy: 0.7040
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 1.0644 - accuracy: 0.6868
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 1.0206 - accuracy: 0.6907
#
#  70/138 [==============>...............]
#  - ETA: 0s - loss: 0.9351 - accuracy: 0.7371
#
#  80/138 [================>.............]
#  - ETA: 0s - loss: 0.9109 - accuracy: 0.7449
#
#  90/138 [==================>...........]
#  - ETA: 0s - loss: 0.8413 - accuracy: 0.7639
#
#  99/138 [====================>.........]
#  - ETA: 0s - loss: 0.8387 - accuracy: 0.7355
#
# 106/138 [======================>.......]
#  - ETA: 0s - loss: 0.8967 - accuracy: 0.7055
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.8794 - accuracy: 0.7017
#
# 126/138 [==========================>...]
#  - ETA: 0s - loss: 0.8184 - accuracy: 0.7225
#
# 137/138 [============================>.]
#  - ETA: 0s - loss: 0.7743 - accuracy: 0.7404
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.7722 - accuracy: 0.7420
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3012835585610925, 'dropout_cnn_block_three': 0.42313087584933406, 'dropout_cnn_block_two': 0.4709438907000862, 'dropout_dense_block_one': 0.6920438973168372, 'dropout_dense_block_two': 0.691459669109377}
# accuracy=0.772207498550415
#   1/138 [..............................]
#  - ETA: 0s - loss: 2.0218 - accuracy: 0.1250
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.3994 - accuracy: 0.8438
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.4996 - accuracy: 0.8305
#
#  37/138 [=======>......................]
#  - ETA: 0s - loss: 0.3678 - accuracy: 0.8784
#
#  50/138 [=========>....................]
#  - ETA: 0s - loss: 0.4337 - accuracy: 0.8413
#
#  61/138 [============>.................]
#  - ETA: 0s - loss: 0.4298 - accuracy: 0.8443
#
#  71/138 [==============>...............]
#  - ETA: 0s - loss: 0.4251 - accuracy: 0.8398
#
#  79/138 [================>.............]
#  - ETA: 0s - loss: 0.3863 - accuracy: 0.8544
#
#  89/138 [==================>...........]
#  - ETA: 0s - loss: 0.3532 - accuracy: 0.8690
#
#  98/138 [====================>.........]
#  - ETA: 0s - loss: 0.3364 - accuracy: 0.8791
#
# 109/138 [======================>.......]
#  - ETA: 0s - loss: 0.3860 - accuracy: 0.8655
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.3608 - accuracy: 0.8747
#
# 129/138 [===========================>..]
#  - ETA: 0s - loss: 0
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.1901 - accuracy: 0.9394
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.1814 - accuracy: 0.9422
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.33120798013198033, 'dropout_cnn_block_three': 0.46290618850288506, 'dropout_cnn_block_two': 0.4480882899924076, 'dropout_dense_block_one': 0.6380426077602896, 'dropout_dense_block_two': 0.3429396908738185}
# accuracy=0.18140386044979095
#   1/138 [..............................]
#  - ETA: 0s - loss: 5.2972 - accuracy: 0.0625
#
#  14/138 [==>...........................]
#  - ETA: 0s - loss: 0.6356 - accuracy: 0.8839
#
#  26/138 [====>.........................]
#  - ETA: 0s - loss: 0.6977 - accuracy: 0.8570
#
#  39/138 [=======>......................]
#  - ETA: 0s - loss: 0.4875 - accuracy: 0.9006
#
#  52/138 [==========>...................]
#  - ETA: 0s - loss: 0.5011 - accuracy: 0.8708
#
#  64/138 [============>.................]
#  - ETA: 0s - loss: 0.4471 - accuracy: 0.8857
#
#  77/138 [===============>..............]
#  - ETA: 0s - loss: 0.4091 - accuracy: 0.8900
#
#  87/138 [=================>............]
#  - ETA: 0s - loss: 0.3662 - accuracy: 0.9016
#
# 100/138 [====================>.........]
#  - ETA: 0s - loss: 0.3640 - accuracy: 0.8969
#
# 111/138 [=======================>......]
#  - ETA: 0s - loss: 0.3792 - accuracy: 0.8919
#
# 123/138 [=========================>....]
#  - ETA: 0s - loss: 0.3423 - accuracy: 0.9024
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.3203 - accuracy: 0.9092
#
# 138/138 [==============================]
#  - 1s 4ms/step - loss: 0.3161 - accuracy: 0.9104
#
# {'batch_size': 160.0, 'dropout_cnn_block_one': 0.3744923219857004, 'dropout_cnn_block_three': 0.49031716891786076, 'dropout_cnn_block_two': 0.4076673881467569, 'dropout_dense_block_one': 0.491420567976277, 'dropout_dense_block_two': 0.6738849318095658}
# accuracy=0.3161299526691437
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.2830 - accuracy: 0.4375
#
#  13/138 [=>............................]
#  - ETA: 0s - loss: 0.2903 - accuracy: 0.9159
#
#  24/138 [====>.........................]
#  - ETA: 0s - loss: 0.5277 - accuracy: 0.8750
#
#  35/138 [======>.......................]
#  - ETA: 0s - loss: 0.3719 - accuracy: 0.9125
#
#  47/138 [=========>....................]
#  - ETA: 0s - loss: 0.4154 - accuracy: 0.8883
#
#  58/138 [===========>..................]
#  - ETA: 0s - loss: 0.3747 - accuracy: 0.8960
#
#  69/138 [==============>...............]
#  - ETA: 0s - loss: 0.3431 - accuracy: 0.9062
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.2967 - accuracy: 0.9194
#
#  91/138 [==================>...........]
#  - ETA: 0s - loss: 0.2745 - accuracy: 0.9258
#
# 101/138 [====================>.........]
#  - ETA: 0s - loss: 0.2659 - accuracy: 0.9291
#
# 110/138 [======================>.......]
#  - ETA: 0s - loss: 0.2889 - accuracy: 0.9239
#
# 121/138 [=========================>....]
#  - ETA: 0s - loss: 0.2627 - accuracy: 0.9308
#
# 130/138 [===========================>..]
#  - ETA: 0s - loss: 0.2566 - accuracy: 0.9315
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.2443 - accuracy: 0.9351
#
# {'batch_size': 140.0, 'dropout_cnn_block_one': 0.3271580163525553, 'dropout_cnn_block_three': 0.45955087990934834, 'dropout_cnn_block_two': 0.4872754101041515, 'dropout_dense_block_one': 0.6689904175560325, 'dropout_dense_block_two': 0.38671081531039253}
# accuracy=0.2443133145570755
#   1/138 [..............................]
#  - ETA: 0s - loss: 1.0268 - accuracy: 0.4688
#
#  11/138 [=>............................]
#  - ETA: 0s - loss: 0.6100 - accuracy: 0.7585
#
#  22/138 [===>..........................]
#  - ETA: 0s - loss: 0.6308 - accuracy: 0.7884
#
#  33/138 [======>.......................]
#  - ETA: 0s - loss: 0.6515 - accuracy: 0.7708
#
#  44/138 [========>.....................]
#  - ETA: 0s - loss: 0.6758 - accuracy: 0.7543
#
#  55/138 [==========>...................]
#  - ETA: 0s - loss: 0.6942 - accuracy: 0.7415
#
#  68/138 [=============>................]
#  - ETA: 0s - loss: 0.6788 - accuracy: 0.7293
#
#  81/138 [================>.............]
#  - ETA: 0s - loss: 0.5802 - accuracy: 0.7666
#
#  93/138 [===================>..........]
#  - ETA: 0s - loss: 0.5208 - accuracy: 0.7964
#
# 105/138 [=====================>........]
#  - ETA: 0s - loss: 0.5831 - accuracy: 0.7824
#
# 117/138 [========================>.....]
#  - ETA: 0s - loss: 0.5610 - accuracy: 0.7887
#
# 124/138 [=========================>....]
#  - ETA: 0s - loss: 0.5405 - accuracy: 0.7986
#
# 136/138 [============================>.]
#  - ETA: 0s - loss: 0.5067 - accuracy: 0.8134
#
# 138/138 [==============================]
#  - 1s 5ms/step - loss: 0.5008 - accuracy: 0.8156
#
# {'batch_size': 200.0, 'dropout_cnn_block_one': 0.300169515180989, 'dropout_cnn_block_three': 0.44798502420187153, 'dropout_cnn_block_two': 0.4699977869033485, 'dropout_dense_block_one': 0.5750274920563558, 'dropout_dense_block_two': 0.6979412467943958}
# accuracy=0.5007755160331726
# 100%|██████████| 30/30 [08:04<00:00, 16.14s/it, best loss: -0.9783859252929688]
